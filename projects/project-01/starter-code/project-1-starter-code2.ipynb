# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
#
# After reading the gushing praise for Pokemon Go you decide to download it and try it out for yourself. Yet a couple hours of play later you find yourself disappointed by the fact that you _actually_ have to move around outside.
#
# Though just a beginner programmer, you decide to make your own iteration on the genre: "Pokemon Stay". In this version players still need to move, but just from website to website. Pokemon gyms are now popular cyber-destinations, and catching pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# ---
#
# #### Package imports
#
# The `pprint` package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create a player. The dictionary and list variables should just be defined as empty at this point.

# %%
player_id = 1
player_name = 'gerty'
time_played = 1.0
player_pokemon = {}
gyms_visited = []

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'amazon.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
# Example output:
# 
# ['amazon.com', 'ebay.com']
gym_list = ['reddit.com','amazon.com','twitter.com','linkedin.com','ebay.com',
            'netflix.com','stackoverflow.com','github.com','quora.com']
gyms_visited.append(gym_list[5])
gyms_visited.append(gym_list[7])
print gyms_visited
# Out:
# ['netflix.com', 'github.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print the pokedex dictionary with the 3 pokemon.

# %%
# No example output... too similar to the answer!
pokedex = {
    1:{
        'name': 'charmander',
        'type':'fire',
        'hp': 2,
        'attack': 2,
        'defense': 3,
        'special_attack': 4,
        'special_defense': 4,
        'speed': 2      
    },
    2:{
        'name': 'squirtle',
        'type':'water',
        'hp': 3,
        'attack': 1,
        'defense': 3,
        'special_attack': 2,
        'special_defense': 4,
        'speed': 4
    },
    3:{
        'name': 'bulbasaur',
        'type':'poison',
        'hp': 5,
        'attack': 5,
        'defense': 5,
        'special_attack': 6,
        'special_defense': 6,
        'speed': 5
    }
}

# %%
pokedex
# Out:
# {1: {'attack': 2,
#   'defense': 3,
#   'hp': 2,
#   'name': 'charmander',
#   'special_attack': 4,
#   'special_defense': 4,
#   'speed': 2,
#   'type': 'fire'},
#  2: {'attack': 1,
#   'defense': 3,
#   'hp': 3,
#   'name': 'squirtle',
#   'special_attack': 2,
#   'special_defense': 4,
#   'speed': 4,
#   'type': 'water'},
#  3: {'attack': 5,
#   'defense': 5,
#   'hp': 5,
#   'name': 'bulbasaur',
#   'special_attack': 6,
#   'special_defense': 6,
#   'speed': 5,
#   'type': 'poison'}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1). **The values in the player's dictionary will be the variables you assigned in question 1.**
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {},
#      'time_played': 0.0}}

playerdex = {}
playerdex[player_id] = {
    'gyms_visited': gyms_visited,
    'player_name': player_name,
    'player_pokemon': {},
    'time_played': time_played    
}

# %%
playerdex
# Out:
# {1: {'gyms_visited': ['netflix.com', 'github.com'],
#   'player_name': 'gerty',
#   'player_pokemon': {},
#   'time_played': 1.0}}

# %%
gv = playerdex[1]['gyms_visited'][0]
gv
# first gym of player_id 1
# Out:
# 'netflix.com'

# %%
playerdex[2] = {
    'gyms_visited': ['github.com', 'amazon.com'],
    'player_name': 'tom',
    'player_pokemon': {},
    'time_played': 333.    
}
playerdex
# Out:
# {1: {'gyms_visited': ['netflix.com', 'github.com'],
#   'player_name': 'gerty',
#   'player_pokemon': {},
#   'time_played': 1.0},
#  2: {'gyms_visited': ['github.com', 'amazon.com'],
#   'player_name': 'tom',
#   'player_pokemon': {},
#   'time_played': 333.0}}

# %%
# print out name of player and gyms visited for player
# .items() - returns keys and values
# .keys()
# .values()

for player in playerdex:
    print playerdex[player]['player_name'], playerdex[player]['gyms_visited']
   
print

for player, player_dict in playerdex.items():
    print player
    print playerdex[player]
    print player_dict
    print player_dict['player_name']
    print
# Out:
# gerty ['netflix.com', 'github.com']
# tom ['github.com', 'amazon.com']
#
# 1
# {'time_played': 1.0, 'gyms_visited': ['netflix.com', 'github.com'], 'player_name': 'gerty', 'player_pokemon': {}}
# {'time_played': 1.0, 'gyms_visited': ['netflix.com', 'github.com'], 'player_name': 'gerty', 'player_pokemon': {}}
# gerty
#
# 2
# {'time_played': 333.0, 'gyms_visited': ['github.com', 'amazon.com'], 'player_name': 'tom', 'player_pokemon': {}}
# {'time_played': 333.0, 'gyms_visited': ['github.com', 'amazon.com'], 'player_name': 'tom', 'player_pokemon': {}}
# tom

# %%
# same with lists in lists

players = [
    ['ash', ['am.com','bullet.com']],
     ['kyle', ['stack.com','git.com']]
]

# print player and gyms
for p in players:
    print p[0], p[1]
# Out:
# ash ['am.com', 'bullet.com']
# kyle ['stack.com', 'git.com']

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'stackoverflow.com'` and `'github.com'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
# No example output. 
player_id = 2
player_name = 'george'
time_played = 9.0
player_pokemon = {}
gyms_visited = ['stackoverflow.com','github.com']

playerdex[player_id] = {
    'gyms_visited': gyms_visited,
    'player_name': player_name,
    'player_pokemon': {},
    'time_played': time_played    
}
playerdex
# Out:
# {1: {'gyms_visited': ['netflix.com', 'github.com'],
#   'player_name': 'gerty',
#   'player_pokemon': {},
#   'time_played': 1.0},
#  2: {'gyms_visited': ['stackoverflow.com', 'github.com'],
#   'player_name': 'george',
#   'player_pokemon': {},
#   'time_played': 9.0}}

# %%
playerdex
# Out:
# {1: {'gyms_visited': ['netflix.com', 'github.com'],
#   'player_name': 'gerty',
#   'player_pokemon': {},
#   'time_played': 1.0},
#  2: {'gyms_visited': ['stackoverflow.com', 'github.com'],
#   'player_name': 'george',
#   'player_pokemon': {},
#   'time_played': 9.0}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {2: ...squirtle dictionary...},
#      'time_played': 0.0},
#  2: {'gyms_visited': ['stackoverflow.com', 'github.com'],
#      'player_name': 'Brock',
#      'player_pokemon': {1: ...charmander dictionary..., 3: ...bulbasaur dictionary...},
#      'time_played': 10.0}}

playerdex[1]['player_pokemon'] = [pokedex[2]]
playerdex[2]['player_pokemon'] = [pokedex[1],pokedex[3]]
print playerdex
# Out:
# {1: {'time_played': 1.0, 'gyms_visited': ['netflix.com', 'github.com'], 'player_name': 'gerty', 'player_pokemon': [{'attack': 1, 'defense': 3, 'name': 'squirtle', 'special_attack': 2, 'speed': 4, 'hp': 3, 'type': 'water', 'special_defense': 4}]}, 2: {'time_played': 9.0, 'gyms_visited': ['stackoverflow.com', 'github.com'], 'player_name': 'george', 'player_pokemon': [{'attack': 2, 'defense': 3, 'name': 'charmander', 'special_attack': 4, 'speed': 2, 'hp': 2, 'type': 'fire', 'special_defense': 4}, {'attack': 5, 'defense': 5, 'name': 'bulbasaur', 'special_attack': 6, 'speed': 5, 'hp': 5, 'type': 'poison', 'special_defense': 6}]}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. What gyms have players visited?
#
# ---
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
# Example output:
#
# Ash has visited amazon.com.
# Ash has visited ebay.com.
# Ash has visited amazon.com.
# Brock has visited stackoverflow.com.
# Brock has visited github.com.

player_gym = []

for gym in gym_list:
    for player in playerdex:
        if gym in playerdex[player]['gyms_visited']:
            print "%s has visited %s." % (playerdex[player]['player_name'], gym)
            
playerdex
# Out:
# gerty has visited netflix.com.
# george has visited stackoverflow.com.
# gerty has visited github.com.
# george has visited github.com.
# {1: {'gyms_visited': ['netflix.com', 'github.com'],
#   'player_name': 'gerty',
#   'player_pokemon': [{'attack': 1,
#     'defense': 3,
#     'hp': 3,
#     'name': 'squirtle',
#     'special_attack': 2,
#     'special_defense': 4,
#     'speed': 4,
#     'type': 'water'}],
#   'time_played': 1.0},
#  2: {'gyms_visited': ['stackoverflow.com', 'github.com'],
#   'player_name': 'george',
#   'player_pokemon': [{'attack': 2,
#     'defense': 3,
#     'hp': 2,
#     'name': 'charmander',
#     'special_attack': 4,
#     'special_defense': 4,
#     'speed': 2,
#     'type': 'fire'},
#    {'attack': 5,
#     'defense': 5,
#     'hp': 5,
#     'name': 'bulbasaur',
#     'special_attack': 6,
#     'special_defense': 6,
#     'speed': 5,
#     'type': 'poison'}],
#   'time_played': 9.0}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
# Example output:
#
# Ash's power is 57.
# 57
# Brock's power is 119.
# 119

def player_power(playerdex, pokedex, player_id):
    sum_power = 0 
    
    for poke in playerdex[player_id]['player_pokemon']:
        sum_power += poke['attack']+poke['special_attack']+poke['defense']+poke['special_defense']
       
    
    print "%s's power is %d." % (playerdex[player_id]['player_name'], sum_power)
    return sum_power

player_power(playerdex, pokedex, 1)
# Out:
# gerty's power is 10.
# 10

# %%
playerdex[1]['player_pokemon']
# Out:
# [{'attack': 1,
#   'defense': 3,
#   'hp': 3,
#   'name': 'squirtle',
#   'special_attack': 2,
#   'special_defense': 4,
#   'speed': 4,
#   'type': 'water'}]

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# Now we have access to the raw base stats on all of the pokemon, scraped from the web.
#
# The provided code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# The first three lists in your pokedex list should look like so:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = '../../../datasets/pokemon/pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.readlines()
    
# the pokedex string is assigned to the raw_pd variable

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# remove returns and quotes
rows = []
for row in raw_pd:
    clean_line = row.replace('\n', '').replace('"', '')
    rows.append(clean_line)

# divide on comma
splitdata = []
for row in rows:
    splitdata.append(row.split(','))

# floatify numbers and replace blank with -1    
cleandata = []
for row in splitdata:
    new_row = []
    for cell in row:
        try:
            cell = float(cell)
        except:
            if cell == '':
                cell = -1.
        new_row.append(cell)
    cleandata.append(new_row)

# split off header
header = cleandata[0]
bodydata = cleandata[1:]

print header
bodydata[0:2]
# Out:
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [[1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]]

# %% [markdown]
# <img src="http://imgur.com/gGrau8s.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
# Example output:
#
# {'Attack': 30.0,
#  'Defense': 50.0,
#  'HP': 40.0,
#  'Name': 'Voltorb',
#  'SpecialAttack': 55.0,
#  'SpecialDefense': 55.0,
#  'Speed': 100.0,
#  'Total': 330.0,
#  'Type': 'Electric'}



def ret_dict(data):


    p_ids = [k[0] for k in data[1:]]
    label_dict = [d for d in data[0]]
    player_dict = {k:[] for k in p_ids}
    row_dict = {d:[] for d in label_dict}
    for pindex, p in enumerate(p_ids):
        for index, column_name in enumerate(data[0]): 
            for row in data[1:3]:
                row_dict[column_name] = row[index]
            player_dict[p] = (row_dict)


    print player_dict
    

                                      
ret_dict(cleandata)
# Out:
# {1.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 2.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 3.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 4.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 5.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 6.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 7.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 8.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 9.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 10.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 11.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 12.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 13.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 14.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 15.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 16.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 17.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 18.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 19.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 20.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 21.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, ...

# %%
print data[100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-cc05140fd8ec> in <module>()
# ----> 1 print data[100]
#
# NameError: name 'data' is not defined

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
filter_options = {
    'Attack':   80,
    'Defense':  80,
    'Type':     'Electric'
}


def gen_filter(filter_crit,pokedex):
    id_list = []
    filters = len(filter_crit)
    num_i = 0
    pkeys = {k:[] for k in header}
    
    for f in filter_options:
        for index, column_name in enumerate(header):
            for row in bodydata:
                if column_name == f and filter_options[f] >= row[index]:
                    id_list.append(row[0])
                     
    for pid in id_list:
        print pokedex[int(pid)]

    #print {k:v[p_id] for k,v in pkeys.items()}
    
gen_filter(filter_options,ret_dict(cleandata))
# Out:
# {1.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 2.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 3.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 4.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 5.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 6.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 7.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 8.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 9.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 10.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 11.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 12.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 13.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 14.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 15.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 16.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 17.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 18.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 19.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 20.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 21.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-f386e4b949a4> in <module>()
#      23     #print {k:v[p_id] for k,v in pkeys.items()}
#      24
# ---> 25 gen_filter(filter_options,ret_dict(cleandata))
#
# <ipython-input-25-f386e4b949a4> in gen_filter(filter_crit, pokedex)
#      19
#      20     for pid in id_list:
# ---> 21         print pokedex[int(pid)]
#      22
#      23     #print {k:v[p_id] for k,v in pkeys.items()}
#
# TypeError: 'NoneType' object has no attribute '__getitem__'
